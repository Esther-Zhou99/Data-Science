# %% [markdown]
# <a href="https://colab.research.google.com/github/Esther-Zhou99/Data-Science/blob/main/Education_Cigarettes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EDA**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_excel("test1.xlsx")
df.set_index("Year", inplace=True)
df.head()
# Out:
#       High School Graduate  ...  Master's, Professional, Doctoral Degree
# Year                        ...
# 1996                   316  ...                                       98
# 1997                   333  ...                                      122
# 1998                   354  ...                                      117
# 1999                   379  ...                                      143
# 2000                   408  ...                                      148
#
# [5 rows x 4 columns]

# %%
sns.set(style="whitegrid")

# %%
ax=df[["High School Graduate", "Associate's Degree","Bachelor's Degree","Master's, Professional, Doctoral Degree"]].plot.barh(
    color={"High School Graduate": "lightblue", "Associate's Degree": "mistyrose","Bachelor's Degree": "salmon", "Master's, Professional, Doctoral Degree": "peachpuff"},stacked=True, figsize=(12, 12)).set_title("Tobacco Products and Smoking Supplies by Education")
fig = ax.get_figure()
fig.savefig('Tobacco Products and Smoking Supplies by Education.png', dpi=600)

# %%
df.describe()
# Out:
#        High School Graduate  ...  Master's, Professional, Doctoral Degree
# count             24.000000  ...                                24.000000
# mean             442.041667  ...                               123.500000
# std               61.267396  ...                                14.322375
# min              316.000000  ...                                97.000000
# 25%              397.250000  ...                               116.000000
# 50%              451.000000  ...                               123.500000
# 75%              491.500000  ...                               131.250000
# max              531.000000  ...                               148.000000
#
# [8 rows x 4 columns]

# %%
sns.boxplot(x=df["High School Graduate"], color="lightblue")

# %%
sns.kdeplot(df["High School Graduate"], shade=True)

# %%
sns.boxplot(x=df["Associate's Degree"], color="mistyrose")

# %%
sns.kdeplot(df["Associate's Degree"], shade=True)

# %%
sns.boxplot(x=df["Bachelor's Degree"], color="salmon")

# %%
sns.kdeplot(df["Bachelor's Degree"], shade=True)

# %%
sns.boxplot(x=df["Master's, Professional, Doctoral Degree"], color="peachpuff")

# %%
sns.kdeplot(df["Master's, Professional, Doctoral Degree"], shade=True)

# %%
for column in df.columns:
    df[column]=pd.to_numeric(df[column])
df.reset_index(inplace=True) 
df.head()
# Out:
#    Year  ...  Master's, Professional, Doctoral Degree
# 0  1996  ...                                       98
# 1  1997  ...                                      122
# 2  1998  ...                                      117
# 3  1999  ...                                      143
# 4  2000  ...                                      148
#
# [5 rows x 5 columns]

# %%
df2= pd.read_excel("test2.xlsx")
df2.head()
# Out:
#    Year     Educational Level  Tobacco Products and Smoking Supplies
# 0  1996  High School Graduate                                    316
# 1  1997  High School Graduate                                    333
# 2  1998  High School Graduate                                    354
# 3  1999  High School Graduate                                    379
# 4  2000  High School Graduate                                    408

# %%
import plotly.io as pio
pio.renderers.default = 'colab'
import plotly.express as px
fig = px.scatter(df2, x='Year', y="Tobacco Products and Smoking Supplies", color="Educational Level")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="43053555-8029-4469-b29b-a6fa8e3a7c11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43053555-8029-4469-b29b-a6fa8e3a7c11")) {
#                     Plotly.newPlot(
#                         '43053555-8029-4469-b29b-a6fa8e3a7c11',
# ...

# %% [markdown]
# # **Time Series Plot**

# %%
df1= pd.read_excel("Consumer price index.xls")
df1.set_index("Date", inplace=True)
df1.head()
# Out:
#             Consumer Price Index
# Date
# 1986-01-01                 121.2
# 1986-02-01                 121.8
# 1986-03-01                 122.4
# 1986-04-01                 123.2
# 1986-05-01                 123.7

# %%
sns.set(style="darkgrid")
fig = sns.relplot(data=df1, kind="line", ci=65)
fig.fig.set_size_inches(35,6)
fig = plt.gcf()
plt.show()
fig.savefig('Consumer Price Index.png', dpi=600)

# %%
df2= pd.read_excel("Producer Price Index.xls")
df2.set_index("Date", inplace=True)
df2.head()
# Out:
#             Producer Price Index by Industry
# Date
# 1965-01-01                              25.8
# 1965-02-01                              25.8
# 1965-03-01                              25.8
# 1965-04-01                              25.8
# 1965-05-01                              25.8

# %%
sns.set(style="darkgrid")
fig = sns.relplot(data=df2, kind="line", ci=65)
fig.fig.set_size_inches(35,6)
fig = plt.gcf()
plt.show()
fig.savefig('Producer Price Index by Industry.png', dpi=600)

# %%
df3= pd.read_excel("Personal consumption expenditures.xls")
df3.set_index("Date", inplace=True)
df3.head()
# Out:
#             Personal consumption expenditures
# Date
# 1929-01-01                              1.695
# 1930-01-01                              1.450
# 1931-01-01                              1.489
# 1932-01-01                              1.322
# 1933-01-01                              1.233

# %%
sns.set(style="darkgrid")
fig = sns.relplot(data=df3, kind="line", ci=65)
fig.fig.set_size_inches(35,6)
fig = plt.gcf()
plt.show()
fig.savefig('Personal consumption expenditures.png', dpi=600)

# %% [markdown]
# # **Regression**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig=sns.lmplot(x="Year", y="Tobacco Products and Smoking Supplies",data=df2, hue="Educational Level",height=7)
fig = plt.gcf()
plt.show()
fig.savefig('regression.png', dpi=600)
